# %%
from pathlib import Path

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import PIL

# %%
main_data_pth = Path('/Users/tsakalis/Downloads/BlastsOnline/')

# %%
ICM = "GT_ICM"
ZP = "GT_ZP"
TE = "GT_TE"

# %%
images_pth = main_data_pth / "Images"

# %%
images_pth / ICM
# Out:
# PosixPath('/Users/tsakalis/Downloads/BlastsOnline/Images/GT_ICM')

# %%
image_ids = [
    str(pth).split('/')[-1][:-4] for pth in list(images_pth.glob('*.BMP'))
]

# %%
images_pth / f"{image_id}.BPM"
# Out:
# PosixPath('/Users/tsakalis/Downloads/BlastsOnline/Images/Blast_PCRM_R13-0524.BPM')

# %%
for image_id in image_ids:

    img = PIL.Image.open(main_data_pth / f"Images/{image_id}.BMP")
    msk_icm = PIL.Image.open(main_data_pth / f"{ICM}/{image_id} ICM_Mask.bmp")
    msk_zp = PIL.Image.open(main_data_pth / f"{ZP}/{image_id} ZP_Mask.bmp")
    msk_te = PIL.Image.open(main_data_pth / f"{ZP}/{image_id}.bmp")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[62], line 6
#       4 msk_icm = PIL.Image.open(main_data_pth / f"{ICM}/{image_id} ICM_Mask.bmp")
#       5 msk_zp = PIL.Image.open(main_data_pth / f"{ZP}/{image_id} ZP_Mask.bmp")
# ----> 6 msk_te = PIL.Image.open(main_data_pth / f"{ZP}/{image_id}.bmp")
#
# File ~/Library/Caches/pypoetry/virtualenvs/cellforge-Tgd_YqAD-py3.11/lib/python3.11/site-packages/PIL/Image.py:3431, in open(fp, mode, formats)
#    3428     filename = os.path.realpath(os.fspath(fp))
#    3430 if filename:
# -> 3431     fp = builtins.open(filename, "rb")
#    3432     exclusive_fp = True
#    3433 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/tsakalis/Downloads/BlastsOnline/GT_ZP/Blast_PCRM_R13-0524.bmp'

# %%
img
# Out:
# <PIL.BmpImagePlugin.BmpImageFile image mode=L size=384x339>

# %%
/Users/tsakalis/Downloads/BlastsOnline/Images
